# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %%
import seaborn as sns

# %%
df1 = pd.read_csv('results.csv')

df1
# Out:
#              date home_team         away_team  home_score  away_score  \
# 0      1872-11-30  Scotland           England         0.0         0.0
# 1      1873-03-08   England          Scotland         4.0         2.0
# 2      1874-03-07  Scotland           England         2.0         1.0
# 3      1875-03-06   England          Scotland         2.0         2.0
# 4      1876-03-04  Scotland           England         3.0         0.0
# ...           ...       ...               ...         ...         ...
# 44055   9/27/2022    Norway            Serbia         0.0         2.0
# 44056   9/27/2022    Sweden          Slovenia         1.0         1.0
# 44057   9/27/2022    Kosovo            Cyprus         5.0         1.0
# 44058   9/27/2022    Greece  Northern Ireland         3.0         1.0
# 44059   9/30/2022      Fiji   Solomon Islands         NaN         NaN
#
#                      tournament        city   country  neutral
# 0                      Friendly     Glasgow  Scotland    False
# ...

# %%
df1.drop('neutral',axis=1,inplace=True)

# %%
df1.head(50)
# Out:
#           date         home_team         away_team  home_score  away_score  \
# 0   1872-11-30          Scotland           England         0.0         0.0
# 1   1873-03-08           England          Scotland         4.0         2.0
# 2   1874-03-07          Scotland           England         2.0         1.0
# 3   1875-03-06           England          Scotland         2.0         2.0
# 4   1876-03-04          Scotland           England         3.0         0.0
# 5   1876-03-25          Scotland             Wales         4.0         0.0
# 6   1877-03-03           England          Scotland         1.0         3.0
# 7   1877-03-05             Wales          Scotland         0.0         2.0
# 8   1878-03-02          Scotland           England         7.0         2.0
# 9   1878-03-23          Scotland             Wales         9.0         0.0
# 10  1879-01-18           England             Wales         2.0         1.0
# ...

# %%
df1.rename(columns = {"date": "Date", "home_team":"Home Team", "away_team":"Away Team", "home_score":"Home Team Score", 
                    "away_score":"Away Team Score", "tournament":"Tournament", "city":"City (Match Played)", 
                      "country":"Country (Match Played)"}, inplace = True)

# %%
df1
# Out:
#              Date Home Team         Away Team  Home Team Score  \
# 0      1872-11-30  Scotland           England              0.0
# 1      1873-03-08   England          Scotland              4.0
# 2      1874-03-07  Scotland           England              2.0
# 3      1875-03-06   England          Scotland              2.0
# 4      1876-03-04  Scotland           England              3.0
# ...           ...       ...               ...              ...
# 44055   9/27/2022    Norway            Serbia              0.0
# 44056   9/27/2022    Sweden          Slovenia              1.0
# 44057   9/27/2022    Kosovo            Cyprus              5.0
# 44058   9/27/2022    Greece  Northern Ireland              3.0
# 44059   9/30/2022      Fiji   Solomon Islands              NaN
#
#        Away Team Score                Tournament City (Match Played)  \
# 0                  0.0                  Friendly             Glasgow
# ...

# %%
df1['Date'] = np.where(df1['Date'].str.contains('/'), pd.to_datetime(df1['Date']).dt.strftime('%m/%d/%Y'), pd.to_datetime(df1['Date'], dayfirst=True).dt.strftime('%m/%d/%Y'))
# Out:
# C:\Users\Mohammad Safayet Khn\AppData\Local\Temp\ipykernel_4196\3328732927.py:1: UserWarning: Parsing '10/21/1906' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['Date'] = np.where(df1['Date'].str.contains('/'), pd.to_datetime(df1['Date']).dt.strftime('%m/%d/%Y'), pd.to_datetime(df1['Date'], dayfirst=True).dt.strftime('%m/%d/%Y'))
# C:\Users\Mohammad Safayet Khn\AppData\Local\Temp\ipykernel_4196\3328732927.py:1: UserWarning: Parsing '10/25/1908' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df1['Date'] = np.where(df1['Date'].str.contains('/'), pd.to_datetime(df1['Date']).dt.strftime('%m/%d/%Y'), pd.to_datetime(df1['Date'], dayfirst=True).dt.strftime('%m/%d/%Y'))
# ...

# %%
df1
# Out:
#              Date Home Team         Away Team  Home Team Score  \
# 0      11/30/1872  Scotland           England              0.0
# 1      03/08/1873   England          Scotland              4.0
# 2      03/07/1874  Scotland           England              2.0
# 3      03/06/1875   England          Scotland              2.0
# 4      03/04/1876  Scotland           England              3.0
# ...           ...       ...               ...              ...
# 44055  09/27/2022    Norway            Serbia              0.0
# 44056  09/27/2022    Sweden          Slovenia              1.0
# 44057  09/27/2022    Kosovo            Cyprus              5.0
# 44058  09/27/2022    Greece  Northern Ireland              3.0
# 44059  09/30/2022      Fiji   Solomon Islands              NaN
#
#        Away Team Score                Tournament City (Match Played)  \
# 0                  0.0                  Friendly             Glasgow
# ...

# %%
conditions = [
    df1['Home Team Score'] > df1['Away Team Score'],
    df1['Home Team Score'] < df1['Away Team Score']]

choices = [df1['Home Team'], df1['Away Team']]

df1['Winner'] = np.select(conditions, choices, default='Draw')

# %%
# df1.head(5)

# %%
# df1.groupby('Home Team')['Winner'].mean

# %%
# df1[(df1['Home Team'] == 'India') & (df1['Away Team'] == 'Taiwan')]

# %%
# df1['Tournament'].unique()

# %%
df1['Outcome Decided'] = 'Normally'

df1
# Out:
#              Date Home Team         Away Team  Home Team Score  \
# 0      11/30/1872  Scotland           England              0.0
# 1      03/08/1873   England          Scotland              4.0
# 2      03/07/1874  Scotland           England              2.0
# 3      03/06/1875   England          Scotland              2.0
# 4      03/04/1876  Scotland           England              3.0
# ...           ...       ...               ...              ...
# 44055  09/27/2022    Norway            Serbia              0.0
# 44056  09/27/2022    Sweden          Slovenia              1.0
# 44057  09/27/2022    Kosovo            Cyprus              5.0
# 44058  09/27/2022    Greece  Northern Ireland              3.0
# 44059  09/30/2022      Fiji   Solomon Islands              NaN
#
#        Away Team Score                Tournament City (Match Played)  \
# 0                  0.0                  Friendly             Glasgow
# ...

# %%
df2 = pd.read_csv('shootouts.csv')

df2
# Out:
#            date    home_team         away_team       winner
# 0    1967-08-22        India            Taiwan       Taiwan
# 1    1971-11-14  South Korea  Vietnam Republic  South Korea
# 2    1972-05-17     Thailand       South Korea  South Korea
# 3    1972-05-19     Thailand          Cambodia     Thailand
# 4    1973-04-21      Senegal             Ghana        Ghana
# ..          ...          ...               ...          ...
# 500  2022-03-29      Senegal             Egypt      Senegal
# 501  2022-06-13    Australia              Peru    Australia
# 502  2022-06-14        Chile             Ghana        Ghana
# 503  2022-09-22     Thailand          Malaysia     Malaysia
# 504  2022-09-25     Malaysia        Tajikistan   Tajikistan
#
# [505 rows x 4 columns]

# %%
df2.rename(columns ={'date':'Date','home_team':'Home Team','away_team':'Away Team','winner':'Winner'}, inplace = True)

# %%
df2
# Out:
#            Date    Home Team         Away Team       Winner
# 0    1967-08-22        India            Taiwan       Taiwan
# 1    1971-11-14  South Korea  Vietnam Republic  South Korea
# 2    1972-05-17     Thailand       South Korea  South Korea
# 3    1972-05-19     Thailand          Cambodia     Thailand
# 4    1973-04-21      Senegal             Ghana        Ghana
# ..          ...          ...               ...          ...
# 500  2022-03-29      Senegal             Egypt      Senegal
# 501  2022-06-13    Australia              Peru    Australia
# 502  2022-06-14        Chile             Ghana        Ghana
# 503  2022-09-22     Thailand          Malaysia     Malaysia
# 504  2022-09-25     Malaysia        Tajikistan   Tajikistan
#
# [505 rows x 4 columns]

# %%
df2['Date'] = np.where(df2['Date'].str.contains('/'), pd.to_datetime(df2['Date']).dt.strftime('%m/%d/%Y'), pd.to_datetime(df2['Date'], dayfirst=True).dt.strftime('%m/%d/%Y'))

# %%
df2['Outcome Decided'] = 'Penalty Shootouts'

df2
# Out:
#            Date    Home Team         Away Team       Winner    Outcome Decided
# 0    08/22/1967        India            Taiwan       Taiwan  Penalty Shootouts
# 1    11/14/1971  South Korea  Vietnam Republic  South Korea  Penalty Shootouts
# 2    05/17/1972     Thailand       South Korea  South Korea  Penalty Shootouts
# 3    05/19/1972     Thailand          Cambodia     Thailand  Penalty Shootouts
# 4    04/21/1973      Senegal             Ghana        Ghana  Penalty Shootouts
# ..          ...          ...               ...          ...                ...
# 500  03/29/2022      Senegal             Egypt      Senegal  Penalty Shootouts
# 501  06/13/2022    Australia              Peru    Australia  Penalty Shootouts
# 502  06/14/2022        Chile             Ghana        Ghana  Penalty Shootouts
# 503  09/22/2022     Thailand          Malaysia     Malaysia  Penalty Shootouts
# 504  09/25/2022     Malaysia        Tajikistan   Tajikistan  Penalty Shootouts
#
# [505 rows x 5 columns]

# %%
df1.head()
# Out:
#          Date Home Team Away Team  Home Team Score  Away Team Score  \
# 0  11/30/1872  Scotland   England              0.0              0.0
# 1  03/08/1873   England  Scotland              4.0              2.0
# 2  03/07/1874  Scotland   England              2.0              1.0
# 3  03/06/1875   England  Scotland              2.0              2.0
# 4  03/04/1876  Scotland   England              3.0              0.0
#
#   Tournament City (Match Played) Country (Match Played)    Winner  \
# 0   Friendly             Glasgow               Scotland      Draw
# 1   Friendly              London                England   England
# 2   Friendly             Glasgow               Scotland  Scotland
# 3   Friendly              London                England      Draw
# 4   Friendly             Glasgow               Scotland  Scotland
#
#   Outcome Decided
# 0        Normally
# 1        Normally
# 2        Normally
# 3        Normally
# 4        Normally

# %%
# df2[(df2['Home Team'] == 'India') & (df2['Away Team'] == 'Taiwan')]

# %%
df2.head()
# Out:
#          Date    Home Team         Away Team       Winner    Outcome Decided
# 0  08/22/1967        India            Taiwan       Taiwan  Penalty Shootouts
# 1  11/14/1971  South Korea  Vietnam Republic  South Korea  Penalty Shootouts
# 2  05/17/1972     Thailand       South Korea  South Korea  Penalty Shootouts
# 3  05/19/1972     Thailand          Cambodia     Thailand  Penalty Shootouts
# 4  04/21/1973      Senegal             Ghana        Ghana  Penalty Shootouts

# %%
# df2.info()

# %%
df2.Winner.value_counts().head(11)
# Out:
# Zambia          13
# South Korea     13
# Egypt           13
# Argentina       12
# South Africa    11
# Thailand        10
# Kenya           10
# Brazil          10
# Senegal          9
# Botswana         8
# Cameroon         8
# Name: Winner, dtype: int64

# %% [markdown]
# ## EDA: Top 10 most successful countries in penalty shootouts

# %%
df2.Winner.value_counts().tail(11)
# Out:
# Hungary                   1
# Romania                   1
# British Virgin Islands    1
# Sri Lanka                 1
# Barbados                  1
# Libya                     1
# Slovenia                  1
# Belarus                   1
# Serbia                    1
# Niger                     1
# Tajikistan                1
# Name: Winner, dtype: int64

# %% [markdown]
# ## EDA: Bottom 10 least successful countries in penalty shootouts

# %%
# df3 = pd.merge(dfR,dfP, left_on=['Date','Home Team'], right_on=['Away Team','Outcome Decided'], how='outer') 

# df3

# %%
# df3 = pd.concat([df1,df2])

# df3

# %%
# sns.heatmap(df3.corr())

# %%
# df3['Tournament'].unique()

# %%
# df3[(df3['Tournament'] == 'British Championship')]

# %%
# df1.groupby('Home Team')['Winner'].mean().nlargest(10)

# %%
for i in df1.index:
    for j in df2.index:
        if df2['Date'][j]==df1['Date'][i] and df2['Home Team'][j]==df1['Home Team'][i] and df2['Away Team'][j]==df1['Away Team'][i]:
            df1['Winner'][i] = df2['Winner'][j]
            df1['Outcome Decided'][i] = df2['Outcome Decided'][j]
# Out:
# C:\Users\Mohammad Safayet Khn\AppData\Local\Temp\ipykernel_4196\3001666445.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Winner'][i] = df2['Winner'][j]
# C:\Users\Mohammad Safayet Khn\AppData\Local\Temp\ipykernel_4196\3001666445.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Outcome Decided'][i] = df2['Outcome Decided'][j]

# %%
df1

# %%
df3 = df1.dropna()

df3

# %%
df3.to_csv('International Football Results from 1872-2022.csv')

# %%
df3.shape

# %%
df3['Tournament'].nunique()

# %%
df3['Winner'].nunique()

# %%
df3.Winner.value_counts().head(11)

# %%
df3.Winner.value_counts().tail(11)

# %%
df3.xs('Home Team', axis=1).value_counts().head(10)

# %%
df3.xs('Away Team', axis=1).value_counts().head(10)

# %%
df3.corr()

# %%
sns.pairplot(df3)

# %%
df3.plot(kind = 'scatter', x = 'Date', y = 'Winner')

# %%
df3.plot(kind = 'scatter', x = 'Home Team', y = 'Home Team Score')

# %%
df3.plot(kind = 'scatter', x = 'Away Team Score', y = 'Home Team Score')

# %%
df3.plot(kind = 'scatter', x = 'Away Team', y = 'Away Team Score')

# %%
Winners = df3.groupby('Home Team')['Winner'].count()

print("Home Team winners", Winners.nlargest())

Winners = df3.groupby('Away Team')['Winner'].count()

print("Away Team winners", Winners.nlargest())

# %%
HomeWinners = df3.groupby('Home Team')['Winner'].count()

print("Home Team winners", HomeWinners)

AwayWinners = df3.groupby('Away Team')['Winner'].count()

print("Away Team winners", AwayWinners)

# %%
print("the Home Win percentages are")

percentage = HomeWinners/(HomeWinners+AwayWinners)
Hpercentage = percentage*100
print(Hpercentage,"%")

# df1[(df1['Home Team'] == 'India') & (df1['Away Team'] == 'Taiwan')]

print("the Away Win percentages are")

percentage = AwayWinners/(HomeWinners+AwayWinners)
Apercentage = percentage*100
print(Apercentage,"%")

# %%
HWinners = df3.groupby('Home Team')['Winner'].count()

AWinners = df3.groupby('Away Team')['Winner'].count()

print("Winners", HWinners )

# %%
df3.groupby('Home Team')['Home Team Score'].nlargest(50)

# %%
df3.groupby('Away Team')['Away Team Score'].mean().nlargest(50)

# %%
print(df3.describe(include='all'))

# %%
df3.info()

# %%
corrmat = df3.corr()
  
f, ax = plt.subplots(figsize =(10, 5))

print(sns.heatmap(corrmat, ax = ax, cmap ="GnBu", linewidths = 0.1))

# %%
df3[["City (Match Played)"]].describe(include="all")

# %%
df3.describe()
